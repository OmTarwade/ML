# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df=df.dropna()

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
df = df.drop(index=0)

# %%
df.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.091830                 -0.081780
# anaemia                   0.091830  1.000000                 -0.190984
# creatinine_phosphokinase -0.081780 -0.190984                  1.000000
# diabetes                 -0.097971 -0.015244                 -0.009650
# ejection_fraction         0.066647  0.027225                 -0.044253
# high_blood_pressure       0.088332  0.042341                 -0.070811
# platelets                -0.052547 -0.043792                  0.024463
# serum_creatinine          0.157666  0.053696                 -0.016415
# serum_sodium             -0.040193  0.037676                  0.059778
# sex                       0.062691 -0.092821                  0.079863
# smoking                   0.021489 -0.109526                  0.002424
# time                     -0.219045 -0.147020                 -0.009387
# DEATH_EVENT               0.249388  0.070863                  0.062951
#
#                           diabetes  ejection_fraction  high_blood_pressure  \
# age                      -0.097971           0.066647             0.088332
# anaemia                  -0.015244           0.027225             0.042341
# creatinine_phosphokinase -0.009650          -0.044253            -0.070811
# diabetes                  1.000000          -0.009251            -0.008905
# ejection_fraction        -0.009251           1.000000             0.031649
# high_blood_pressure      -0.008905           0.031649             1.000000
# platelets                 0.092352           0.072550             0.050042
# serum_creatinine         -0.045655          -0.008824            -0.007195
# serum_sodium             -0.094300           0.169487             0.044275
# sex                      -0.155967          -0.145311            -0.108405
# smoking                  -0.149428          -0.071183            -0.052780
# time                      0.029257           0.033642            -0.190446
# DEATH_EVENT               0.002204          -0.263102             0.073205
#
#                           platelets  serum_creatinine  serum_sodium       sex  \
# age                       -0.052547          0.157666     -0.040193  0.062691
# anaemia                   -0.043792          0.053696      0.037676 -0.092821
# creatinine_phosphokinase   0.024463         -0.016415      0.059778  0.079863
# diabetes                   0.092352         -0.045655     -0.094300 -0.155967
# ejection_fraction          0.072550         -0.008824      0.169487 -0.145311
# high_blood_pressure        0.050042         -0.007195      0.044275 -0.108405
# platelets                  1.000000         -0.041242      0.062447 -0.125276
# serum_creatinine          -0.041242          1.000000     -0.187410  0.005768
# serum_sodium               0.062447         -0.187410      1.000000 -0.023966
# sex                       -0.125276          0.005768     -0.023966  1.000000
# smoking                    0.028296         -0.026315      0.001349  0.448352
# time                       0.010653         -0.147353      0.080076 -0.011648
# DEATH_EVENT               -0.049397          0.293045     -0.189254 -0.007942
#
#                            smoking      time  DEATH_EVENT
# age                       0.021489 -0.219045     0.249388
# anaemia                  -0.109526 -0.147020     0.070863
# creatinine_phosphokinase  0.002424 -0.009387     0.062951
# diabetes                 -0.149428  0.029257     0.002204
# ejection_fraction        -0.071183  0.033642    -0.263102
# high_blood_pressure      -0.052780 -0.190446     0.073205
# platelets                 0.028296  0.010653    -0.049397
# serum_creatinine         -0.026315 -0.147353     0.293045
# serum_sodium              0.001349  0.080076    -0.189254
# sex                       0.448352 -0.011648    -0.007942
# smoking                   1.000000 -0.026740    -0.009308
# time                     -0.026740  1.000000    -0.523200
# DEATH_EVENT              -0.009308 -0.523200     1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 1 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       298 non-null    float64
#  1   anaemia                   298 non-null    int64
#  2   creatinine_phosphokinase  298 non-null    int64
#  3   diabetes                  298 non-null    int64
#  4   ejection_fraction         298 non-null    int64
#  5   high_blood_pressure       298 non-null    int64
#  6   platelets                 298 non-null    float64
#  7   serum_creatinine          298 non-null    float64
#  8   serum_sodium              298 non-null    int64
#  9   sex                       298 non-null    int64
#  10  smoking                   298 non-null    int64
#  11  time                      298 non-null    int64
#  12  DEATH_EVENT               298 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.4 KB

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  298.000000  298.000000                298.000000  298.000000
# mean    60.786356    0.432886                581.838926    0.419463
# std     11.886333    0.496309                971.919989    0.494301
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                115.750000    0.000000
# 50%     60.000000    0.000000                249.500000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         298.000000           298.000000     298.000000
# mean           38.144295             0.348993  263352.519295
# std            11.808060             0.477454   97968.705617
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212250.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303750.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex     smoking        time  \
# count        298.000000    298.000000  298.000000  298.000000  298.000000
# mean           1.392181    136.647651    0.647651    0.322148  130.684564
# std            1.035833      4.403092    0.478506    0.468085   77.397621
# min            0.500000    113.000000    0.000000    0.000000    6.000000
# 25%            0.900000    134.000000    0.000000    0.000000   73.250000
# 50%            1.100000    137.000000    1.000000    0.000000  115.000000
# 75%            1.400000    140.000000    1.000000    1.000000  204.000000
# max            9.400000    148.000000    1.000000    1.000000  285.000000
#
#        DEATH_EVENT
# count   298.000000
# mean      0.318792
# std       0.466792
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 5    90.0        1                        47         0                 40
# 6    75.0        1                       246         0                 15
# 8    65.0        0                       157         0                 65
# ..    ...      ...                       ...       ...                ...
# 291  60.0        0                       320         0                 35
# 292  52.0        0                       190         1                 38
# 293  63.0        1                       103         1                 35
# 294  62.0        0                        61         1                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 5                      1  204000.00               2.1           132    1
# 6                      0  127000.00               1.2           137    1
# 8                      0  263358.03               1.5           138    0
# ..                   ...        ...               ...           ...  ...
# 291                    0  133000.00               1.4           139    1
# 292                    0  382000.00               1.0           140    1
# 293                    0  179000.00               0.9           136    1
# 294                    1  155000.00               1.1           143    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 2          1     7            1
# 3          0     7            1
# 5          1     8            1
# 6          0    10            1
# 8          0    10            1
# ..       ...   ...          ...
# 291        0   258            0
# 292        1   258            0
# 293        1   270            0
# 294        1   270            0
# 298        1   285            0
#
# [223 rows x 13 columns]

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  223.000000  223.000000                223.000000  223.000000
# mean    60.745892    0.470852                335.843049    0.421525
# std     11.934850    0.500273                279.664547    0.494914
# min     40.000000    0.000000                 30.000000    0.000000
# 25%     50.000000    0.000000                114.000000    0.000000
# 50%     60.000000    0.000000                212.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               1202.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         223.000000           223.000000     223.000000
# mean           38.260090             0.376682  255824.226771
# std            11.673276             0.485644   67302.021363
# min            14.000000             0.000000  122000.000000
# 25%            30.000000             0.000000  210000.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  297500.000000
# max            65.000000             1.000000  427000.000000
#
#        serum_creatinine  serum_sodium         sex     smoking        time  \
# count        223.000000    223.000000  223.000000  223.000000  223.000000
# mean           1.125112    137.076233    0.641256    0.322870  133.228700
# std            0.324408      3.785763    0.480711    0.468625   76.262625
# min            0.600000    125.000000    0.000000    0.000000    7.000000
# 25%            0.900000    134.500000    0.000000    0.000000   77.000000
# 50%            1.100000    137.000000    1.000000    0.000000  120.000000
# 75%            1.300000    140.000000    1.000000    1.000000  205.000000
# max            2.100000    148.000000    1.000000    1.000000  285.000000
#
#        DEATH_EVENT
# count   223.000000
# mean      0.269058
# std       0.444468
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
X=df.drop('DEATH_EVENT',axis=1)
y=df['DEATH_EVENT']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.3574117739971584

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import f1_score,r2_score

# %%
f1=f1_score(y_test,y_pred)

# %%
f1
# Out:
# 0.6956521739130435

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
f1=f1_score(y_test,y_pred)

# %%
f1
# Out:
# 0.6086956521739131

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
f1=f1_score(y_test,y_pred)

# %%
f1
# Out:
# 0.5217391304347826

# %%
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
f1=f1_score(y_test,y_pred)

# %%
f1
# Out:
# 0.5217391304347826

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test_scaled)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[28  3]
#  [ 8  6]]

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7555555555555555

# %%
input_data = np.array([[75, 0, 582, 0, 20, 1, 265000, 1.9, 130, 1, 0, 4]])
input_scaled = scaler.transform(input_data)
prediction = model.predict(input_scaled)
print(prediction)
# Out:
# [1]
# c:\users\asus\appdata\local\programs\python\python38\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
